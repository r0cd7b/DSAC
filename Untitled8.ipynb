# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.4.0.42-cp38-cp38-win_amd64.whl (33.5 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sanggyun\anaconda3\lib\site-packages (from opencv-python) (1.18.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.4.0.42

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('families.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img.shape
# Out:
# (1810, 2716, 3)

# %%
cascade_file = "haar.xml"
cascade = cv2.CascadeClassifier(cascade_file)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
face_list = cascade.detectMultiScale(img_gray, minSize=(150, 150))

if len(face_list) == 0:
    print("no face !")
    quit()

for (x, y, w, h) in face_list:
    print("face 좌표: ", x, y, w, h)
    red = (0, 0, 255)
    cv2.rectangle(img, (x, y), (x + w, y + h), red, thickness=20)
# Out:
# face 좌표:  671 137 391 391
# face 좌표:  2064 533 351 351
# face 좌표:  482 552 393 393
# face 좌표:  1735 231 315 315
# face 좌표:  1465 899 333 333
# face 좌표:  1124 389 402 402

# %%
cv2.imwrite("face-detect.png", img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
