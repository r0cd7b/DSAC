# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

iris = load_iris()
X, y = iris.data[:, :2], iris.target

plt.xlim(4, 8.5)
plt.ylim(1.5, 4.5)

markers = ['o', '+', '^']
for i in range(3):
    xs = X[:, 0][y == i]
    ys = X[:, 1][y == i]
    plt.scatter(xs, ys, marker=markers[i])

plt.legend(iris.target_names)
plt.xlabel("sepal length")
plt.ylabel("sepal width")

xx = np.linspace(5.45, 5.45, 3)
yy = np.linspace(1.5, 4.5, 3)
plt.plot(xx, yy, "-k")

xx = np.linspace(4, 5.45, 3)
yy = np.linspace(2.8, 2.8, 3)
plt.plot(xx, yy, "--b")

xx = np.linspace(6.15, 6.15, 3)
yy = np.linspace(1.5, 4.5, 3)
plt.plot(xx, yy, "--r")

np.random.seed(0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
for i in range(2, 10):
    clf = DecisionTreeClassifier(max_depth=i)
    clf.fit(X_train, y_train)
    print(f"i = {i}, train = {clf.score(X_train, y_train).round(2)}, test = {clf.score(X_test, y_test).round(2)}")
# Out:
# i = 2, train = 0.79, test = 0.57
# i = 3, train = 0.83, test = 0.6
# i = 4, train = 0.85, test = 0.6
# i = 5, train = 0.87, test = 0.63
# i = 6, train = 0.89, test = 0.7
# i = 7, train = 0.89, test = 0.7
# i = 8, train = 0.92, test = 0.63
# i = 9, train = 0.92, test = 0.67

# %%
from sklearn import tree

tree.plot_tree(clf, filled=True)
# Out:
# [Text(111.39485294117648, 206.56799999999998, 'X[0] <= 5.45\ngini = 0.665\nsamples = 120\nvalue = [39, 37, 44]'),
#  Text(39.38823529411765, 184.824, 'X[1] <= 2.85\ngini = 0.256\nsamples = 41\nvalue = [35, 5, 1]'),
#  Text(19.694117647058825, 163.07999999999998, 'X[0] <= 4.7\ngini = 0.5\nsamples = 6\nvalue = [1, 4, 1]'),
#  Text(9.847058823529412, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(29.541176470588237, 141.336, 'X[0] <= 4.95\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(19.694117647058825, 119.592, 'X[1] <= 2.45\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(9.847058823529412, 97.848, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(29.541176470588237, 97.848, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(39.38823529411765, 119.592, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(59.082352941176474, 163.07999999999998, 'X[0] <= 5.35\ngini = 0.056\nsamples = 35\nvalue = [34, 1, 0]'),
#  Text(49.23529411764706, 141.336, 'gini = 0.0\nsamples = 30\nvalue = [30, 0, 0]'),
#  Text(68.92941176470589, 141.336, 'X[1] <= 3.2\ngini = 0.32\nsamples = 5\nvalue = [4, 1, 0]'),
#  Text(59.082352941176474, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(78.7764705882353, 119.592, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(183.4014705882353, 184.824, 'X[0] <= 5.95\ngini = 0.537\nsamples = 79\nvalue = [4, 32, 43]'),
#  Text(128.01176470588237, 163.07999999999998, 'X[1] <= 3.35\ngini = 0.473\nsamples = 26\nvalue = [4, 18, 4]'),
#  Text(118.16470588235295, 141.336, 'X[0] <= 5.75\ngini = 0.298\nsamples = 22\nvalue = [0, 18, 4]'),
#  Text(98.47058823529412, 119.592, 'X[1] <= 2.55\ngini = 0.133\nsamples = 14\nvalue = [0, 13, 1]'),
#  Text(88.62352941176471, 97.848, 'X[0] <= 5.65\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(78.7764705882353, 76.10399999999998, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(98.47058823529412, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(108.31764705882354, 97.848, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0]'),
#  Text(137.85882352941178, 119.592, 'X[1] <= 2.65\ngini = 0.469\nsamples = 8\nvalue = [0, 5, 3]'),
#  Text(128.01176470588237, 97.848, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(147.7058823529412, 97.848, 'X[1] <= 3.1\ngini = 0.49\nsamples = 7\nvalue = [0, 4, 3]'),
#  Text(137.85882352941178, 76.10399999999998, 'X[0] <= 5.85\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 3]'),
#  Text(128.01176470588237, 54.360000000000014, 'gini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(147.7058823529412, 54.360000000000014, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(157.5529411764706, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(137.85882352941178, 141.336, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(238.79117647058825, 163.07999999999998, 'X[0] <= 7.05\ngini = 0.389\nsamples = 53\nvalue = [0, 14, 39]'),
#  Text(228.94411764705885, 141.336, 'X[0] <= 6.95\ngini = 0.444\nsamples = 42\nvalue = [0, 14, 28]'),
#  Text(219.09705882352944, 119.592, 'X[1] <= 2.4\ngini = 0.433\nsamples = 41\nvalue = [0, 13, 28]'),
#  Text(187.09411764705882, 97.848, 'X[0] <= 6.1\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(177.24705882352941, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(196.94117647058823, 76.10399999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(251.10000000000002, 97.848, 'X[0] <= 6.15\ngini = 0.411\nsamples = 38\nvalue = [0, 11, 27]'),
#  Text(216.63529411764708, 76.10399999999998, 'X[1] <= 2.85\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2]'),
#  Text(206.78823529411767, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(226.4823529411765, 54.360000000000014, 'X[1] <= 3.2\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(216.63529411764708, 32.615999999999985, 'X[0] <= 6.05\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(206.78823529411767, 10.872000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(226.4823529411765, 10.872000000000014, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(236.3294117647059, 32.615999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(285.56470588235294, 76.10399999999998, 'X[0] <= 6.55\ngini = 0.367\nsamples = 33\nvalue = [0, 8, 25]'),
#  Text(265.8705882352941, 54.360000000000014, 'X[1] <= 2.6\ngini = 0.278\nsamples = 18\nvalue = [0, 3, 15]'),
#  Text(256.02352941176474, 32.615999999999985, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(275.71764705882356, 32.615999999999985, 'X[1] <= 3.25\ngini = 0.219\nsamples = 16\nvalue = [0, 2, 14]'),
#  Text(265.8705882352941, 10.872000000000014, 'gini = 0.142\nsamples = 13\nvalue = [0, 1, 12]'),
#  Text(285.56470588235294, 10.872000000000014, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(305.25882352941176, 54.360000000000014, 'X[0] <= 6.65\ngini = 0.444\nsamples = 15\nvalue = [0, 5, 10]'),
#  Text(295.4117647058824, 32.615999999999985, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(315.1058823529412, 32.615999999999985, 'X[1] <= 3.15\ngini = 0.355\nsamples = 13\nvalue = [0, 3, 10]'),
#  Text(305.25882352941176, 10.872000000000014, 'gini = 0.444\nsamples = 9\nvalue = [0, 3, 6]'),
#  Text(324.95294117647063, 10.872000000000014, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(238.79117647058825, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(248.63823529411766, 141.336, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11]')]

# %%
clf.predict_proba([[5.5, 4]])
# Out:
# array([[1., 0., 0.]])
